# %% [markdown]
# # Data Science Course Week 2 - Lesson 2
# # Introduction to Linear Regression

# %% [markdown]
# Regression is the process of learning a mapping from a vector of input data to a quantitative output given a set of observations. For example, coordinates in a room to Wi-Fi signal strength, someone's Body Mass Index to their life expectancy or a stock's performance over the last 5 days to it's value tomorrow.
#
# There are numerous methods for addressing this problem, each with their own set of assumptions and behaviour. Some are ideal for tackling large volumes of data while others provide more informative probabilistic outputs.
#
# In this lab, we'll focus on Linear Regression; a good point of reference for many other regression techniques and still used widely around the world today due to their simplicity and favourable scaling characteristics.

# %% [markdown]
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %% [markdown]
# # Class Workshop

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %% [markdown]
# Here we are using a dataset of chicago house prices. The dataset is made up of houses that sold and several variables that describe the data.

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", index_col=0)

# %%
house_data.head(30)
# Out:
#                                  Address Neighborhood           HouseType  \
# 0      2111 W Division St #5, Chicago IL  Wicker Park               Condo
# 1        1520 W Walton St #2, Chicago IL  Wicker Park               Condo
# 2           2047 W Thomas St, Chicago IL  Wicker Park   Multi-Family Home
# 3     1735 N Paulina St #314, Chicago IL  Wicker Park               Condo
# 4           1634 W Beach Ave, Chicago IL  Wicker Park   Multi-Family Home
# 5        1634 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 6         1440 N Wood St #2F, Chicago IL  Wicker Park               Condo
# 7         1137 N Wood St #F2, Chicago IL  Wicker Park               Condo
# 8            1418 N Bell Ave, Chicago IL  Wicker Park   Multi-Family Home
# 9        1308 N Bosworth Ave, Chicago IL  Wicker Park   Multi-Family Home
# 10            1025 N Wood St, Chicago IL  Wicker Park   Multi-Family Home
# 11         1732 W Pierce Ave, Chicago IL  Wicker Park   Multi-Family Home
# 12    1449 N Ashland Ave #1R, Chicago IL  Wicker Park               Condo
# 13        2116 W Potomac Ave, Chicago IL  Wicker Park   Multi-Family Home
# 14            1421 N Wood St, Chicago IL  Wicker Park  Single-Family Home
# 15     1332 N Wolcott Ave #1, Chicago IL  Wicker Park               Condo
# 16        1411 N Ashland Ave, Chicago IL  Wicker Park   Multi-Family Home
# 17        1409 N Ashland Ave, Chicago IL  Wicker Park   Multi-Family Home
# 18       1019 N Honore St #1, Chicago IL  Wicker Park               Condo
# 19           2152 W Caton St, Chicago IL  Wicker Park  Single-Family Home
# 20      1735 N Hermitage Ave, Chicago IL  Wicker Park  Single-Family Home
# 21  2300 W Wabansia Ave #124, Chicago IL  Wicker Park               Condo
# 22   1026 N Hermitage Ave #2, Chicago IL  Wicker Park                 NaN
# 23     1725 W Le Moyne St #2, Chicago IL  Wicker Park   Multi-Family Home
# 24  2089 W Wabansia Ave #307, Chicago IL  Wicker Park               Condo
# 25       1637 W Beach Ave #1, Chicago IL  Wicker Park               Condo
# 26       922 N Hermitage Ave, Chicago IL  Wicker Park   Multi-Family Home
# 27      1111 N Hermitage Ave, Chicago IL  Wicker Park               Condo
# 28    1548 N Bosworth Ave #1, Chicago IL  Wicker Park               Condo
# 29       1544 W Thomas St #2, Chicago IL  Wicker Park               Condo
#
#      Price  Bath  CrimeIndex  MinutesToLoop  MilesToLake  Age  LotSizeSqft  \
# 0   390000   NaN        2.59              9         3.91    0            0
# 1   320500   NaN        4.10              7         3.02    0            0
# 2   620000   4.0        2.09              9         3.84   94         3049
# 3   318000   NaN        2.40              9         2.90    0            0
# 4   477000   2.0        4.63              9         2.96   31         2614
# 5   695000   2.0        1.40              8         2.86   23         2614
# 6   242500   NaN        5.38              9         3.22    0            0
# 7   477500   NaN        4.18              8         3.39    0            0
# 8   466000   2.0        4.93             10         4.02  121         3049
# 9   435000   2.0        4.75              8         2.89  119         3485
# 10  303000   2.0        4.68              8         3.43  119         3049
# 11  314000   3.0        5.18              9         3.06  131         2614
# 12  146500   NaN        4.50              8         2.86    0            0
# 13  650000   3.0        3.89             10         3.86  119         3485
# 14  490500   1.0        5.38              9         3.21  124         2614
# 15  341000   NaN        5.88              9         3.40    0            0
# 16  590000   2.0        4.50              8         2.90  118         2614
# 17  590000   2.0        4.50              8         2.90  119         2614
# 18  535000   NaN        3.99              9         3.52    0            0
# 19  885000   3.0        5.58             11         3.72  121         4792
# 20  982500   3.0        4.65              9         2.98    0         2614
# 21  280000   NaN        8.08             11         3.95    0            0
# 22  380000   NaN        5.68              9         3.37    0            0
# 23  580000   3.0        5.18              9         3.08  108         2614
# 24  392500   NaN        5.58             10         3.58    0            0
# 25  267500   NaN        4.63              9         2.97    0            0
# 26  398000   2.0        4.23              8         3.42  116         3049
# 27  350000   NaN        5.38              8         3.29    0            0
# 28  359000   NaN        4.30              8         2.77    0            0
# 29  315000   NaN        5.30              7         2.98    0            0
#
#     HouseSizeSqft  SchoolIndex  EstimatedPrice
# 0               0         36.2        335790.0
# 1               0         91.7        376908.0
# 2            3492         36.2        629300.0
# 3               0         50.0        297330.0
# 4            1840         78.9        463644.0
# 5            1628         50.0        813150.0
# 6               0         69.4        196667.5
# 7               0         59.5        445030.0
# 8            1344         16.7        538696.0
# 9            1760         40.0        463275.0
# 10           2728         59.5        361782.0
# 11           2405         50.0        334724.0
# 12              0         78.9        139468.0
# 13           3618         16.7        680550.0
# 14            922         69.4        516987.0
# 15              0         69.4        282689.0
# 16           2544         78.9        589410.0
# 17           2352         78.9        644870.0
# 18              0         59.5        523230.0
# 19           3461         36.1        945180.0
# 20           2783         33.3       1087627.5
# 21              0         36.1        292320.0
# 22              0         22.2        449160.0
# 23           2656         50.0        596820.0
# 24              0         36.1        369342.5
# 25              0         78.9        288365.0
# 26           1344         22.2        364170.0
# 27              0         59.5        306950.0
# 28              0         50.0        357205.0
# 29              0         27.3        279405.0

# %%
# do we have any missing data?
house_data.isnull().sum() 

#missing bath
# Out:
# Address             0
# Neighborhood        0
# HouseType           3
# Price               0
# Bath              149
# CrimeIndex          0
# MinutesToLoop       0
# MilesToLake         0
# Age                 0
# LotSizeSqft         0
# HouseSizeSqft       0
# SchoolIndex         0
# EstimatedPrice      0
# dtype: int64

# %%
# Summarise the data
house_data.describe()
#house_data.describe(include=['object'])
#house_data.describe(include='all')
# Out:
#               Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count  2.190000e+02  70.000000  219.000000     219.000000   219.000000
# mean   4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std    4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min    2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%    3.190000e+05   2.000000    3.940000       8.000000     3.150000
# 50%    3.900000e+05   2.000000    4.930000       9.000000     3.400000
# 75%    5.125000e+05   3.000000    5.580000      10.000000     3.685000
# max    3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#               Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count  219.000000   219.000000     219.000000   219.000000    2.190000e+02
# mean    29.424658   873.200913     699.977169    49.197717    4.862191e+05
# std     49.155880  1392.893683    1175.278922    18.554525    3.978582e+05
# min      0.000000     0.000000       0.000000    16.700000    2.883650e+04
# 25%      0.000000     0.000000       0.000000    36.100000    3.074488e+05
# 50%      0.000000     0.000000       0.000000    50.000000    3.919800e+05
# 75%     41.000000  2614.000000    1344.000000    59.500000    5.324750e+05
# max    131.000000  7405.000000    6422.000000    93.900000    3.973508e+06

# %%
# Look for any linear correlations in the data
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# Bath           -0.039220    -0.029979       0.698526    -0.047992
# CrimeIndex     -0.036644    -0.008807       0.070952    -0.100256
# MinutesToLoop  -0.023820    -0.053292      -0.032437    -0.196728
# MilesToLake    -0.047087     0.006240      -0.046517    -0.205966
# Age             1.000000     0.716774       0.645147    -0.029953
# LotSizeSqft     0.716774     1.000000       0.828598    -0.055458
# HouseSizeSqft   0.645147     0.828598       1.000000    -0.023378
# SchoolIndex    -0.029953    -0.055458      -0.023378     1.000000
# EstimatedPrice  0.255628     0.454939       0.471783    -0.073825
#
#                 EstimatedPrice
# Price                 0.983784
# Bath                  0.105632
# CrimeIndex            0.122793
# MinutesToLoop        -0.034185
# MilesToLake          -0.082604
# Age                   0.255628
# LotSizeSqft           0.454939
# HouseSizeSqft         0.471783
# SchoolIndex          -0.073825
# EstimatedPrice        1.000000

# %%
# Plot each variable against each other 
# scroll down past the subplot information
pd.plotting.scatter_matrix(house_data, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48B05F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48C30588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48E0C128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48C3BDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48E703C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48E70400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48EE1320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48F19400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF48F42860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4918ABE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF491C3B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF491FEA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49195E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4926A390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF492A0390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF492DA860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49313DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4933FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49376BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF493B0BE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF493EABE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49380CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF494556A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4948EB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF494D00F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF494EDF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49535160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4956E4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49583EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF495DE470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4960ABE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4963EBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF496840F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF496BC630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF496590F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF497226A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF497586A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49790B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF497CAB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF497FF1D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49837240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF498711D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF498AB1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF498D2E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4990BEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49946E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49979E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF499644E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF499E9A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49A22A90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49A5CA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49A91EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49AC7550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49B02470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49B3B390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49B73390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49AD8160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49BD3B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49C0FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49C49B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49C7EA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49CA0D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49CE7160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49D20160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49D59080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49D20D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49DBB940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49DF6940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49E2F860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49E65DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49E9B400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49ED5390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49F0D2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49F472B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49EAACF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49FA7A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF49FE2B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A01DA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A054A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A086550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A0BF9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A0F99B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A133940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A165550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A19D5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A1D84E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A20F470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A220128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A26EFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A2B52B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A2D2128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A3280F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A352A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A389A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A3C2EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A3FDEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A3AE9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A467550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A4A09B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF4A4DA9B0>]], dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
#
#
# - What looks to be affecting house prices from our initial inspection?
# bath, crime index,milesto lake, housesize
#
# - What is the type of relationship in those variables affecting price?

# %%
# create a fitted model in one line
lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft', data=house_data, missing = 'drop').fit()

# print the coefficients!
print(lm.params)
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %% [markdown]
# The summary function provided by the statsmodel library presents lots of useful information about the resulting model.
#
# Key items to pay attention to are:
# - R-squared
# - Adj. R-Squared
# - coef (for each variable)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Sat, 03 Mar 2018   Prob (F-statistic):              0.269
# Time:                        12:29:12   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016    9.89e+04    9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803   -2.61e+05    2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187     -66.297     332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 -28995.66*3 + 133*350
# Out:
# 467873.02

# %% [markdown]
# ## Student Excercise

# %% [markdown]
# Now try creating a regression from just the EstimatedPrice

# %%
# check the distribution of Price vs. EstimatedPrice using a scatterplot
import seaborn as sns
sns.set_style("darkgrid")

sns.lmplot(y='Price', x='EstimatedPrice', data=house_data)

# %%
# Let's try just modelling just using the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Sat, 03 Mar 2018   Prob (F-statistic):          6.25e-164
# Time:                        12:38:07   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758   -1.28e+04    1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000       0.965       1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Question:
# Did the model build on just Estimated Price have a better R-Squared value than the prior model built using Bath and HouseSizeSqft?

# %% [markdown]
# ### Predicting Price using the built model

# %% [markdown]
# Now we will find out what the model estimates the price will be for the the minimum and maximium values of EstimatedPrice

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
# these values will be be used in the built model to predict the Price
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
# predict price given two data points and the built model

preds = lm.predict(X_new)
preds
# Out:
# 0    3.090156e+04
# 1    3.933717e+06
# dtype: float64

# %% [markdown]
# Now lets view a line representing the model build off just Estimated Price, over a scatter plot of the data of Price vs. EstimatedPrice.
#
# To produce the line overlay, we will simply plot a straight line between the two predicted points over the scatter plot.

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# %%
# Now, plot a line over the points that uses just the two points
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')
# this code overlays a straight line between the the coordinates created by X_new and preds
plt.plot(X_new, preds, c='red', linewidth=2)

# %% [markdown]
# ### Experiment
# Now try creating new models by selecting different variables or combinations of variables. Can you get a better fit?

# %%
# create a fitted model in one line
new_model = smf.ols(formula='Price ~ Age + LotSizeSqft', data=house_data, missing = 'drop').fit()
print(new_model.params)
new_model.summary()
# Out:
# Intercept      382057.365160
# Age             -1340.186379
# LotSizeSqft       161.255226
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     28.66
# Date:                Sat, 03 Mar 2018   Prob (F-statistic):           9.11e-12
# Time:                        13:41:27   Log-Likelihood:                -3109.5
# No. Observations:                 219   AIC:                             6225.
# Df Residuals:                     216   BIC:                             6235.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    3.821e+05    2.9e+04     13.181      0.000    3.25e+05    4.39e+05
# Age         -1340.1864    706.086     -1.898      0.059   -2731.886      51.514
# LotSizeSqft   161.2552     24.918      6.471      0.000     112.141     210.369
# ==============================================================================
# Omnibus:                      285.491   Durbin-Watson:                   1.373
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18713.406
# Skew:                           5.668   Prob(JB):                         0.00
# Kurtosis:                      46.844   Cond. No.                     1.97e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.97e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# create a fitted model in one line
new_model2 = smf.ols(formula='Price ~ np.sqrt(Age) + LotSizeSqft', data=house_data, missing = 'drop').fit()
print(new_model.params)
new_model2.summary()
# Out:
# Intercept       384829.345251
# np.sqrt(Age)    -15454.698556
# LotSizeSqft        164.436656
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.211
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     28.93
# Date:                Sat, 03 Mar 2018   Prob (F-statistic):           7.36e-12
# Time:                        13:41:24   Log-Likelihood:                -3109.3
# No. Observations:                 219   AIC:                             6225.
# Df Residuals:                     216   BIC:                             6235.
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     3.848e+05   2.92e+04     13.192      0.000    3.27e+05    4.42e+05
# np.sqrt(Age) -1.545e+04   7692.644     -2.009      0.046   -3.06e+04    -292.440
# LotSizeSqft    164.4367     25.338      6.490      0.000     114.496     214.377
# ==============================================================================
# Omnibus:                      285.230   Durbin-Watson:                   1.371
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18651.386
# Skew:                           5.660   Prob(JB):                         0.00
# Kurtosis:                      46.771   Cond. No.                     1.99e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.99e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
house_data['sqrt_age'] = np.sqrt(house_data['Age'])
#house_data.plot(kind='scatter', x=np.sqrt('Age'), y='Price')
house_data.head()
# Out:
#                               Address Neighborhood          HouseType   Price  \
# 0   2111 W Division St #5, Chicago IL  Wicker Park              Condo  390000
# 1     1520 W Walton St #2, Chicago IL  Wicker Park              Condo  320500
# 2        2047 W Thomas St, Chicago IL  Wicker Park  Multi-Family Home  620000
# 3  1735 N Paulina St #314, Chicago IL  Wicker Park              Condo  318000
# 4        1634 W Beach Ave, Chicago IL  Wicker Park  Multi-Family Home  477000
#
#    Bath  CrimeIndex  MinutesToLoop  MilesToLake  Age  LotSizeSqft  \
# 0   NaN        2.59              9         3.91    0            0
# 1   NaN        4.10              7         3.02    0            0
# 2   4.0        2.09              9         3.84   94         3049
# 3   NaN        2.40              9         2.90    0            0
# 4   2.0        4.63              9         2.96   31         2614
#
#    HouseSizeSqft  SchoolIndex  EstimatedPrice  sqrt_age
# 0              0         36.2        335790.0  0.000000
# 1              0         91.7        376908.0  0.000000
# 2           3492         36.2        629300.0  9.695360
# 3              0         50.0        297330.0  0.000000
# 4           1840         78.9        463644.0  5.567764

# %%
house_data.plot(kind='scatter', x='sqrt_age', y='Price')

# %% [markdown]
# ## Themepark

# %% [markdown]
# The file **themepark.csv** has some data from a theme park. Children were asked to rate their experience on a scale
# from 0-5. This data was compared against the number of hours they spent in the park.

# %%
theme_park_data = pd.read_csv("themepark.csv")
theme_park_data.head()
# Out:
#    Hours  Enjoyment
# 0      1          1
# 1      2          3
# 2      3          4
# 3      4          5
# 4      5          5

# %%
# Create a pandas DataFrame from this data by reading it in using pandas. 
# It is located in the same directory as this notebook, so you will not need to provide a filepath.

# %%
# Have a look at the data (e.g. display the head or tail, use describe, etc.)
theme_park_data.tail()
theme_park_data.describe()
# Out:
#            Hours  Enjoyment
# count  27.000000  27.000000
# mean    2.740741   3.148148
# std     1.456883   1.610153
# min     1.000000   0.000000
# 25%     1.500000   2.000000
# 50%     3.000000   3.000000
# 75%     4.000000   4.500000
# max     5.000000   5.000000

# %%
# Draw a scatterplot of this data
theme_park_data.plot(kind='scatter', x='Hours', y = 'Enjoyment')

# %%
# Try doing a linear regression on this data
lr_theme_park = smf.ols(formula='Hours ~ Enjoyment', data=theme_park_data).fit()

x1 = theme_park_data.Hours.min()
x2 = theme_park_data.Hours.max()

x_theme_park = pd.DataFrame({'Enjoyment': [x1,x2]})

print(x_theme_park)
pred_theme_park = lr_theme_park.predict(x_theme_park)

print(pred_theme_park)
# Out:
#    Enjoyment
# 0          1
# 1          5
# 0    1.146154
# 1    4.115385
# dtype: float64

# %%
lr_theme_park.params
# Out:
# Intercept    0.403846
# Enjoyment    0.742308
# dtype: float64

# %%
# Plot this regression over the top of the data. Could the regression be better?
new_plot =theme_park_data.plot(kind='scatter', x='Hours', y='Enjoyment')
plt.plot(x_theme_park,pred_theme_park,c='red',linewidth=2)

# %%
# Plot this regression over the top of the data. Could the regression be better?
new_plot =theme_park_data.plot(kind='scatter', x='Hours', y='Enjoyment')
